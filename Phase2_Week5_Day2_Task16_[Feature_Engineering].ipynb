# %% [markdown]
# #Data Preparation

# %% [markdown]
# Read the Titanic.csv file into a DataFrame using pandas.
# Check for any missing values and handle them appropriately.
# Drop columns that won't be used in the model (e.g., Ticket, Name, Cabin).

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Phase2/Week5/Day2/Copy of Titanic.csv")
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(['Age','Cabin','Ticket'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#       Fare Embarked
# 0   7.2500        S
# 1  71.2833        C
# 2   7.9250        S
# 3  53.1000        S
# 4   8.0500        S

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #Encoding Categorical Variables

# %% [markdown]
# Encode the Sex column (e.g., Male = 1, Female = 0).
# Use LabelEncoder or OneHotEncoder for categorical variables

# %%
df['Sex'] = df['Sex'].map({'male': 1, 'female': 0})

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Embarked'] = le.fit_transform(df['Embarked'])

# %% [markdown]
# #Create New Features

# %% [markdown]
# Extract titles from the Name column (e.g., Mr, Mrs, Miss) and create a new feature called Title.

# %%
df['Title'] = df['Name'].str.extract(r',\s*([^\.]+)\.')
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name  Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0      1      0
# 2                             Heikkinen, Miss. Laina    0      0      0
#
#       Fare  Embarked Title
# 0   7.2500         2    Mr
# 1  71.2833         0   Mrs
# 2   7.9250         2  Miss

# %% [markdown]
# Create a FamilySize feature that combines the SibSp (siblings/spouses aboard) and Parch (parents/children aboard) columns.

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %% [markdown]
# Create a IsAlone feature that indicates whether a passenger is traveling alone (FamilySize = 1).

# %%
df['IsAlone'] = (df['FamilySize'] == 1).astype(int)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0      1      0
# 2                             Heikkinen, Miss. Laina    0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0      1      0
# 4                           Allen, Mr. William Henry    1      0      0
#
#       Fare  Embarked Title  FamilySize  IsAlone
# 0   7.2500         2    Mr           2        0
# 1  71.2833         0   Mrs           2        0
# 2   7.9250         2  Miss           1        1
# 3  53.1000         2   Mrs           2        0
# 4   8.0500         2    Mr           1        1

# %%
df = df.drop(columns=['Name'])
df['Title'] = le.fit_transform(df['Title'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Fare         891 non-null    float64
#  7   Embarked     891 non-null    int64
#  8   Title        891 non-null    int64
#  9   FamilySize   891 non-null    int64
#  10  IsAlone      891 non-null    int64
# dtypes: float64(1), int64(10)
# memory usage: 76.7 KB

# %% [markdown]
# #Preprocess the Data

# %% [markdown]
# Split the dataset into features (X) and target (y).
# Split the data into training and testing sets using train_test_split.

# %%
y = df.Survived
X = df.drop("Survived",axis=1)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=1, stratify=y
)

# %% [markdown]
# #Define the Objective Function

# %% [markdown]
# Create an objective function for Optuna that:
# Suggests hyperparameters for a model (e.g., GradientBoostingClassifier).
# Trains the model on the training set.
# Evaluates the model on the testing set.
# Returns the accuracy.

# %%
from sklearn.tree import DecisionTreeClassifier

# Create and train the Decision Tree model
model = DecisionTreeClassifier(max_depth=2, max_leaf_nodes=8, random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, max_leaf_nodes=8, random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Make predictions on the testing set
y_pred = model.predict(X_test)

accuracy=accuracy_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
precision = precision_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Recall Score:", recall)
print("Precision Score:", precision)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.7555555555555555
# Recall Score: 0.6857142857142857
# Precision Score: 0.6857142857142857
# F1 Score: 0.6857142857142857

# %%
import optuna
# Define the objective function for Optuna
def objective(trial):
    # Define the search space for hyperparameters
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 7),  # int
        'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 5, 12),  # int
        'splitter': trial.suggest_categorical('splitter', ['best', 'random']),  # categorical
        'min_weight_fraction_leaf': trial.suggest_float('min_weight_fraction_leaf', 0.0, 0.5),  # float
        'random_state': trial.suggest_int('random_state', 1, 100),  # int
    }

    # Create and train the model with suggested hyperparameters
    model = DecisionTreeClassifier(**params)
    model.fit(X_train, y_train)

    # Evaluate the model's performance on the validation set
    predictions = model.predict(X_test)
    f1 = f1_score(y_test, predictions)

    return f1

# %% [markdown]
# #Set Up Optuna Study

# %% [markdown]
# Create an Optuna study to optimize the objective function.
# Run the optimization for a specified number of trials (e.g., 100)

# %%
# Create a study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-06-14 13:01:48,319] A new study created in memory with name: no-name-4f2494cf-bac1-49da-8fb6-422179a70f05
# [I 2025-06-14 13:01:48,334] Trial 0 finished with value: 0.676923076923077 and parameters: {'max_depth': 6, 'max_leaf_nodes': 8, 'splitter': 'best', 'min_weight_fraction_leaf': 0.21235294473770533, 'random_state': 36}. Best is trial 0 with value: 0.676923076923077.
# [I 2025-06-14 13:01:48,352] Trial 1 finished with value: 0.676923076923077 and parameters: {'max_depth': 3, 'max_leaf_nodes': 9, 'splitter': 'random', 'min_weight_fraction_leaf': 0.1481304214260537, 'random_state': 34}. Best is trial 0 with value: 0.676923076923077.
# [I 2025-06-14 13:01:48,366] Trial 2 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.12134641153284981, 'random_state': 28}. Best is trial 0 with value: 0.676923076923077.
# [I 2025-06-14 13:01:48,380] Trial 3 finished with value: 0.6764705882352942 and parameters: {'max_depth': 6, 'max_leaf_nodes': 7, 'splitter': 'best', 'min_weight_fraction_leaf': 0.41909315614093934, 'random_state': 8}. Best is trial 0 with value: 0.676923076923077.
# [I 2025-06-14 13:01:48,395] Trial 4 finished with value: 0.676923076923077 and parameters: {'max_depth': 6, 'max_leaf_nodes': 12, 'splitter': 'best', 'min_weight_fraction_leaf': 0.2658909667970981, 'random_state': 86}. Best is trial 0 with value: 0.676923076923077.
# [I 2025-06-14 13:01:48,409] Trial 5 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 12, 'splitter': 'best', 'min_weight_fraction_leaf': 0.08420529314251063, 'random_state': 59}. Best is trial 0 with value: 0.676923076923077.
# [I 2025-06-14 13:01:48,425] Trial 6 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 8, 'splitter': 'best', 'min_weight_fraction_leaf': 0.1419354492705865, 'random_state': 19}. Best is trial 0 with value: 0.676923076923077.
# [I 2025-06-14 13:01:48,440] Trial 7 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 12, 'splitter': 'random', 'min_weight_fraction_leaf': 0.26419613651005086, 'random_state': 85}. Best is trial 0 with value: 0.676923076923077.
# [I 2025-06-14 13:01:48,457] Trial 8 finished with value: 0.676923076923077 and parameters: {'max_depth': 6, 'max_leaf_nodes': 10, 'splitter': 'best', 'min_weight_fraction_leaf': 0.28530059092368265, 'random_state': 75}. Best is trial 0 with value: 0.676923076923077.
# [I 2025-06-14 13:01:48,477] Trial 9 finished with value: 0.7058823529411765 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.030975538207727193, 'random_state': 56}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:48,522] Trial 10 finished with value: 0.6557377049180327 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'random', 'min_weight_fraction_leaf': 0.011416011638652402, 'random_state': 51}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:48,574] Trial 11 finished with value: 0.6764705882352942 and parameters: {'max_depth': 7, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.39373053537079816, 'random_state': 41}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:48,623] Trial 12 finished with value: 0.6865671641791045 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.007682138230782686, 'random_state': 66}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:48,673] Trial 13 finished with value: 0.6865671641791045 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.006999799556491992, 'random_state': 65}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:48,721] Trial 14 finished with value: 0.7017543859649122 and parameters: {'max_depth': 3, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.06161626621008323, 'random_state': 96}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:48,772] Trial 15 finished with value: 0.6557377049180327 and parameters: {'max_depth': 3, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.07029431024458899, 'random_state': 90}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:48,832] Trial 16 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.33678675928561086, 'random_state': 76}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:48,902] Trial 17 finished with value: 0.631578947368421 and parameters: {'max_depth': 4, 'max_leaf_nodes': 7, 'splitter': 'best', 'min_weight_fraction_leaf': 0.4961736358263587, 'random_state': 96}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:48,952] Trial 18 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.19824755896748172, 'random_state': 49}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,004] Trial 19 finished with value: 0.6557377049180327 and parameters: {'max_depth': 3, 'max_leaf_nodes': 10, 'splitter': 'best', 'min_weight_fraction_leaf': 0.0665194323256503, 'random_state': 97}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,054] Trial 20 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.18400894789062944, 'random_state': 1}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,107] Trial 21 finished with value: 0.6865671641791045 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.0009897833188306105, 'random_state': 66}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,159] Trial 22 finished with value: 0.6857142857142857 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.05957763424598429, 'random_state': 77}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,209] Trial 23 finished with value: 0.6857142857142857 and parameters: {'max_depth': 6, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.04896029790736915, 'random_state': 56}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,257] Trial 24 finished with value: 0.676923076923077 and parameters: {'max_depth': 7, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.10664360837583454, 'random_state': 68}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,317] Trial 25 finished with value: 0.65625 and parameters: {'max_depth': 6, 'max_leaf_nodes': 7, 'splitter': 'best', 'min_weight_fraction_leaf': 0.037052052697226764, 'random_state': 47}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,367] Trial 26 finished with value: 0.676923076923077 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'random', 'min_weight_fraction_leaf': 0.10684547323381252, 'random_state': 80}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,421] Trial 27 finished with value: 0.65625 and parameters: {'max_depth': 3, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.03743473584081107, 'random_state': 100}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,469] Trial 28 finished with value: 0.676923076923077 and parameters: {'max_depth': 6, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.17024219654379008, 'random_state': 59}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,518] Trial 29 finished with value: 0.676923076923077 and parameters: {'max_depth': 6, 'max_leaf_nodes': 9, 'splitter': 'best', 'min_weight_fraction_leaf': 0.09310290651714825, 'random_state': 37}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,566] Trial 30 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 7, 'splitter': 'best', 'min_weight_fraction_leaf': 0.21827323437935955, 'random_state': 68}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,614] Trial 31 finished with value: 0.6865671641791045 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.006311044543048215, 'random_state': 63}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,665] Trial 32 finished with value: 0.6865671641791045 and parameters: {'max_depth': 7, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.02417233131498077, 'random_state': 70}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,715] Trial 33 finished with value: 0.676923076923077 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.12611056837511117, 'random_state': 54}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,765] Trial 34 finished with value: 0.7017543859649122 and parameters: {'max_depth': 5, 'max_leaf_nodes': 6, 'splitter': 'random', 'min_weight_fraction_leaf': 0.03397272284235675, 'random_state': 29}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,817] Trial 35 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.1481116212666869, 'random_state': 25}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,869] Trial 36 finished with value: 0.6101694915254238 and parameters: {'max_depth': 3, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.046460614503230684, 'random_state': 28}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,931] Trial 37 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 6, 'splitter': 'random', 'min_weight_fraction_leaf': 0.07495572329083902, 'random_state': 17}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:49,997] Trial 38 finished with value: 0.676923076923077 and parameters: {'max_depth': 6, 'max_leaf_nodes': 11, 'splitter': 'random', 'min_weight_fraction_leaf': 0.22816790888856153, 'random_state': 41}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,060] Trial 39 finished with value: 0.676923076923077 and parameters: {'max_depth': 6, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.11920876309825118, 'random_state': 44}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,125] Trial 40 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 9, 'splitter': 'random', 'min_weight_fraction_leaf': 0.08896949024029494, 'random_state': 32}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,194] Trial 41 finished with value: 0.6865671641791045 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.024406500102501352, 'random_state': 86}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,262] Trial 42 finished with value: 0.6875 and parameters: {'max_depth': 7, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.0016730836869607718, 'random_state': 63}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,331] Trial 43 finished with value: 0.65625 and parameters: {'max_depth': 6, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.03318379709580384, 'random_state': 61}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,397] Trial 44 finished with value: 0.7017543859649122 and parameters: {'max_depth': 7, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.05362517129341328, 'random_state': 14}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,462] Trial 45 finished with value: 0.676923076923077 and parameters: {'max_depth': 7, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.3056170752571273, 'random_state': 10}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,518] Trial 46 finished with value: 0.7017543859649122 and parameters: {'max_depth': 4, 'max_leaf_nodes': 6, 'splitter': 'random', 'min_weight_fraction_leaf': 0.05965402162846053, 'random_state': 20}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,575] Trial 47 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.16389889510320477, 'random_state': 20}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,638] Trial 48 finished with value: 0.676923076923077 and parameters: {'max_depth': 3, 'max_leaf_nodes': 6, 'splitter': 'random', 'min_weight_fraction_leaf': 0.08693722917118257, 'random_state': 11}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,702] Trial 49 finished with value: 0.676923076923077 and parameters: {'max_depth': 3, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.13335604638688262, 'random_state': 15}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,761] Trial 50 finished with value: 0.6101694915254238 and parameters: {'max_depth': 4, 'max_leaf_nodes': 6, 'splitter': 'random', 'min_weight_fraction_leaf': 0.05432069617932817, 'random_state': 4}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,816] Trial 51 finished with value: 0.6101694915254238 and parameters: {'max_depth': 4, 'max_leaf_nodes': 6, 'splitter': 'random', 'min_weight_fraction_leaf': 0.06490178730631162, 'random_state': 23}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,875] Trial 52 finished with value: 0.6101694915254238 and parameters: {'max_depth': 3, 'max_leaf_nodes': 6, 'splitter': 'random', 'min_weight_fraction_leaf': 0.014034475458120331, 'random_state': 32}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:50,938] Trial 53 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.10324728469217193, 'random_state': 6}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,003] Trial 54 finished with value: 0.6865671641791045 and parameters: {'max_depth': 7, 'max_leaf_nodes': 6, 'splitter': 'random', 'min_weight_fraction_leaf': 0.026248622659467827, 'random_state': 13}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,075] Trial 55 finished with value: 0.0 and parameters: {'max_depth': 5, 'max_leaf_nodes': 5, 'splitter': 'random', 'min_weight_fraction_leaf': 0.38756138661046374, 'random_state': 21}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,133] Trial 56 finished with value: 0.7017543859649122 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.051842560623460175, 'random_state': 37}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,180] Trial 57 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.07444484140707575, 'random_state': 28}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,215] Trial 58 finished with value: 0.7017543859649122 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.047006763676333316, 'random_state': 34}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,250] Trial 59 finished with value: 0.6101694915254238 and parameters: {'max_depth': 5, 'max_leaf_nodes': 9, 'splitter': 'random', 'min_weight_fraction_leaf': 0.06222788634858667, 'random_state': 39}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,285] Trial 60 finished with value: 0.0 and parameters: {'max_depth': 4, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.45950922850328607, 'random_state': 25}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,321] Trial 61 finished with value: 0.7017543859649122 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.0503295885477717, 'random_state': 35}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,357] Trial 62 finished with value: 0.6101694915254238 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.039176230792788536, 'random_state': 44}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,393] Trial 63 finished with value: 0.676923076923077 and parameters: {'max_depth': 3, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.0796549521265341, 'random_state': 31}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,431] Trial 64 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 9, 'splitter': 'random', 'min_weight_fraction_leaf': 0.10452095796741155, 'random_state': 18}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,468] Trial 65 finished with value: 0.6774193548387096 and parameters: {'max_depth': 5, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.015599448995721188, 'random_state': 36}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,508] Trial 66 finished with value: 0.7017543859649122 and parameters: {'max_depth': 3, 'max_leaf_nodes': 10, 'splitter': 'random', 'min_weight_fraction_leaf': 0.04968159167545541, 'random_state': 26}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,549] Trial 67 finished with value: 0.6557377049180327 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.029330906544338935, 'random_state': 53}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,587] Trial 68 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 5, 'splitter': 'random', 'min_weight_fraction_leaf': 0.11397188575940806, 'random_state': 90}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,623] Trial 69 finished with value: 0.6101694915254238 and parameters: {'max_depth': 4, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.06475044027781485, 'random_state': 22}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,660] Trial 70 finished with value: 0.676923076923077 and parameters: {'max_depth': 3, 'max_leaf_nodes': 9, 'splitter': 'best', 'min_weight_fraction_leaf': 0.09054008314147652, 'random_state': 29}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,697] Trial 71 finished with value: 0.7017543859649122 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.04913763169415221, 'random_state': 34}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,735] Trial 72 finished with value: 0.6101694915254238 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.04159387452749919, 'random_state': 45}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,772] Trial 73 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.017694483185117692, 'random_state': 39}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,810] Trial 74 finished with value: 0.6101694915254238 and parameters: {'max_depth': 4, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.05538696927462741, 'random_state': 35}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,852] Trial 75 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 9, 'splitter': 'random', 'min_weight_fraction_leaf': 0.07943067155667136, 'random_state': 16}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,892] Trial 76 finished with value: 0.676923076923077 and parameters: {'max_depth': 6, 'max_leaf_nodes': 7, 'splitter': 'best', 'min_weight_fraction_leaf': 0.09638069935439067, 'random_state': 48}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,929] Trial 77 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.13463665744851577, 'random_state': 73}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:51,966] Trial 78 finished with value: 0.676923076923077 and parameters: {'max_depth': 3, 'max_leaf_nodes': 5, 'splitter': 'random', 'min_weight_fraction_leaf': 0.029218098708757353, 'random_state': 42}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,006] Trial 79 finished with value: 0.6875 and parameters: {'max_depth': 5, 'max_leaf_nodes': 6, 'splitter': 'best', 'min_weight_fraction_leaf': 0.0027066631818567916, 'random_state': 30}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,043] Trial 80 finished with value: 0.676923076923077 and parameters: {'max_depth': 5, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.07088860526755822, 'random_state': 38}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,099] Trial 81 finished with value: 0.7017543859649122 and parameters: {'max_depth': 3, 'max_leaf_nodes': 10, 'splitter': 'random', 'min_weight_fraction_leaf': 0.04902709805714537, 'random_state': 24}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,147] Trial 82 finished with value: 0.6349206349206349 and parameters: {'max_depth': 3, 'max_leaf_nodes': 12, 'splitter': 'random', 'min_weight_fraction_leaf': 0.04075144486918919, 'random_state': 28}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,188] Trial 83 finished with value: 0.7017543859649122 and parameters: {'max_depth': 3, 'max_leaf_nodes': 10, 'splitter': 'random', 'min_weight_fraction_leaf': 0.05472035995279849, 'random_state': 26}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,230] Trial 84 finished with value: 0.6875 and parameters: {'max_depth': 3, 'max_leaf_nodes': 11, 'splitter': 'random', 'min_weight_fraction_leaf': 0.014777048741413099, 'random_state': 13}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,274] Trial 85 finished with value: 0.6557377049180327 and parameters: {'max_depth': 3, 'max_leaf_nodes': 9, 'splitter': 'best', 'min_weight_fraction_leaf': 0.06439192411443559, 'random_state': 33}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,319] Trial 86 finished with value: 0.6349206349206349 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.03578977351640499, 'random_state': 83}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,363] Trial 87 finished with value: 0.676923076923077 and parameters: {'max_depth': 3, 'max_leaf_nodes': 6, 'splitter': 'random', 'min_weight_fraction_leaf': 0.08632951067937594, 'random_state': 20}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,408] Trial 88 finished with value: 0.676923076923077 and parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.2513372085390604, 'random_state': 26}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,453] Trial 89 finished with value: 0.676923076923077 and parameters: {'max_depth': 6, 'max_leaf_nodes': 11, 'splitter': 'random', 'min_weight_fraction_leaf': 0.3329794794024341, 'random_state': 14}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,497] Trial 90 finished with value: 0.6101694915254238 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.0197744025178703, 'random_state': 10}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,542] Trial 91 finished with value: 0.7017543859649122 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.04898510182890029, 'random_state': 33}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,588] Trial 92 finished with value: 0.7017543859649122 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.05268185192486354, 'random_state': 36}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,632] Trial 93 finished with value: 0.676923076923077 and parameters: {'max_depth': 4, 'max_leaf_nodes': 8, 'splitter': 'random', 'min_weight_fraction_leaf': 0.06989216826532853, 'random_state': 42}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,677] Trial 94 finished with value: 0.7017543859649122 and parameters: {'max_depth': 4, 'max_leaf_nodes': 7, 'splitter': 'random', 'min_weight_fraction_leaf': 0.04355150535171419, 'random_state': 34}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,728] Trial 95 finished with value: 0.6865671641791045 and parameters: {'max_depth': 4, 'max_leaf_nodes': 10, 'splitter': 'random', 'min_weight_fraction_leaf': 0.000148496308719534, 'random_state': 51}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,775] Trial 96 finished with value: 0.7058823529411765 and parameters: {'max_depth': 3, 'max_leaf_nodes': 9, 'splitter': 'best', 'min_weight_fraction_leaf': 0.0314932325193998, 'random_state': 19}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,820] Trial 97 finished with value: 0.6666666666666666 and parameters: {'max_depth': 3, 'max_leaf_nodes': 9, 'splitter': 'best', 'min_weight_fraction_leaf': 0.024043028109651546, 'random_state': 17}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,865] Trial 98 finished with value: 0.6557377049180327 and parameters: {'max_depth': 3, 'max_leaf_nodes': 11, 'splitter': 'best', 'min_weight_fraction_leaf': 0.07694007508596706, 'random_state': 22}. Best is trial 9 with value: 0.7058823529411765.
# [I 2025-06-14 13:01:52,910] Trial 99 finished with value: 0.65625 and parameters: {'max_depth': 3, 'max_leaf_nodes': 10, 'splitter': 'best', 'min_weight_fraction_leaf': 0.03579009419641615, 'random_state': 8}. Best is trial 9 with value: 0.7058823529411765.

# %% [markdown]
# #Retrieve and Display Results

# %% [markdown]
# Access the best hyperparameters found during the optimization.

# %%
# Access the best parameters
best_params = study.best_params
print("Best Parameters:", best_params)

# Access the best score
best_score = study.best_value
print("Best Score:", best_score)
# Out:
# Best Parameters: {'max_depth': 7, 'max_leaf_nodes': 5, 'splitter': 'best', 'min_weight_fraction_leaf': 0.030975538207727193, 'random_state': 56}
# Best Score: 0.7058823529411765

# %% [markdown]
# Train a final model using these best parameters on the entire training data.
# Evaluate this model on the test dataset and display the accuracy.

# %%
# Create a new model with the best parameters
final_model = DecisionTreeClassifier(**best_params)

# Fit the model on the entire training data
final_model.fit(X_train, y_train)

# Predict on the test data
y_pred = final_model.predict(X_test)

# Evaluate the model's performance
final_accuracy = accuracy_score(y_test, y_pred)
print("Final Model Accuracy on Test Data:", final_accuracy)
# Out:
# Final Model Accuracy on Test Data: 0.7777777777777778

# %%
accuracy=accuracy_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
precision = precision_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Recall Score:", recall)
print("Precision Score:", precision)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.7777777777777778
# Recall Score: 0.6857142857142857
# Precision Score: 0.7272727272727273
# F1 Score: 0.7058823529411765
